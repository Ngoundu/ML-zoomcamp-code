# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('data.csv')

# %%
df = pd.DataFrame(data,columns=columns)

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df.loc[:,"Make"]
# Out:
# 0            BMW
# 1            BMW
# 2            BMW
# 3            BMW
# 4            BMW
#           ...
# 11909      Acura
# 11910      Acura
# 11911      Acura
# 11912      Acura
# 11913    Lincoln
# Name: Make, Length: 11914, dtype: object

# %%
df.loc[:,"Make"]
# Out:
# 0            BMW
# 1            BMW
# 2            BMW
# 3            BMW
# 4            BMW
#           ...
# 11909      Acura
# 11910      Acura
# 11911      Acura
# 11912      Acura
# 11913    Lincoln
# Name: Make, Length: 11914, dtype: object

# %%
df.groupby(["Make"]).first()
# Out:
#                             Model  Year                Engine Fuel Type  \
# Make
# Acura                          CL  2001     premium unleaded (required)
# Alfa Romeo                     4C  2015     premium unleaded (required)
# Aston Martin                  DB7  2003     premium unleaded (required)
# Audi                          100  1992                regular unleaded
# BMW                    1 Series M  2011     premium unleaded (required)
# Bentley                    Arnage  2007     premium unleaded (required)
# Bugatti               Veyron 16.4  2008     premium unleaded (required)
# Buick                     Cascada  2016  premium unleaded (recommended)
# Cadillac                  Allante  1991                regular unleaded
# Chevrolet             Astro Cargo  2003                regular unleaded
# Chrysler                      200  2015        flex-fuel (unleaded/E85)
# Dodge                     Avenger  2012        flex-fuel (unleaded/E85)
# ...

# %%
df.nunique()
# Out:
# Make                   48
# Model                 915
# Year                   28
# Engine Fuel Type       10
# Engine HP             356
# Engine Cylinders        9
# Transmission Type       5
# Driven_Wheels           4
# Number of Doors         3
# Market Category        71
# Vehicle Size            3
# Vehicle Style          16
# highway MPG            59
# city mpg               69
# Popularity             48
# MSRP                 6049
# dtype: int64

# %%
df.nunique(axis=1)
# Out:
# 0        16
# 1        16
# 2        16
# 3        16
# 4        16
#          ..
# 11909    16
# 11910    16
# 11911    16
# 11912    16
# 11913    16
# Length: 11914, dtype: int64

# %%
df.groupby('Make').nunique()
# Out:
#                Model  Year  Engine Fuel Type  Engine HP  Engine Cylinders  \
# Make
# Acura             18    22                 3         27                 3
# Alfa Romeo         1     2                 1          1                 1
# Aston Martin      12    11                 1         13                 2
# Audi              34    20                 5         40                 6
# BMW               39    18                 5         37                 5
# Bentley           18    12                 2         16                 2
# Bugatti            1     2                 1          1                 1
# Buick             20    19                 4         29                 3
# Cadillac          30    25                 5         32                 3
# Chevrolet         63    27                 7         68                 6
# Chrysler          19    23                 3         27                 3
# Dodge             33    27                 4         58                 4
# ...

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
ec=df.loc[:,"Engine Cylinders"]

# %%
ec
# Out:
# 0        6.0
# 1        6.0
# 2        6.0
# 3        6.0
# 4        6.0
#         ...
# 11909    6.0
# 11910    6.0
# 11911    6.0
# 11912    6.0
# 11913    6.0
# Name: Engine Cylinders, Length: 11914, dtype: float64

# %%
d=(ec.fillna(4.0))
d
# Out:
# 0        6.0
# 1        6.0
# 2        6.0
# 3        6.0
# 4        6.0
#         ...
# 11909    6.0
# 11910    6.0
# 11911    6.0
# 11912    6.0
# 11913    6.0
# Name: Engine Cylinders, Length: 11914, dtype: float64

# %%
M=ec.mode()
M
# Out:
# 0    4.0
# Name: Engine Cylinders, dtype: float64

# %%
x=ec.mean()
x
# Out:
# 5.628828677213059

# %%
d.median()
# Out:
# 6.0

# %%
df.Make.index
# Out:
# RangeIndex(start=0, stop=11914, step=1)

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df[['Engine HP','Engine Cylinders']]
# Out:
#        Engine HP  Engine Cylinders
# 0          335.0               6.0
# 1          300.0               6.0
# 2          300.0               6.0
# 3          230.0               6.0
# 4          230.0               6.0
# ...          ...               ...
# 11909      300.0               6.0
# 11910      300.0               6.0
# 11911      300.0               6.0
# 11912      300.0               6.0
# 11913      221.0               6.0
#
# [11914 rows x 2 columns]
