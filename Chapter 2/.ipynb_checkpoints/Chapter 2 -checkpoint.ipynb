# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('house/housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.median_house_value
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %%
sns.histplot(df.median_house_value,bins=50)
# EDA of median_house_value
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='Count'>

# %%
median_logs=np.log1p(df.median_house_value)

# %%
sns.histplot(median_logs,bins=50)
# EDA of log of median_house_value
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='Count'>

# %%
df.isnull().sum()
# Question 1
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
pp=df.loc[:,'population']

# %%
pp
# Out:
# 0         322.0
# 1        2401.0
# 2         496.0
# 3         558.0
# 4         565.0
#           ...
# 20635     845.0
# 20636     356.0
# 20637    1007.0
# 20638     741.0
# 20639    1387.0
# Name: population, Length: 20640, dtype: float64

# %%
md=pp.median()
# question 2

# %%
md
# Out:
# 1166.0

# %%
df1=df.fillna(0)
df1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
n=len(df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 n=len(df1)
#
# NameError: name 'df1' is not defined

# %%
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 n
#
# NameError: name 'n' is not defined

# %%
idx=np.arange(n)

# %%
np.random.seed(42)

# %%
np.random.shuffle(idx)

# %%
df1_shuffled=df1.iloc[idx]

# %%
df1_shuffled[['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income']]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20046    -119.01     36.06                25.0       1505.0             0.0
# 3024     -119.46     35.14                30.0       2943.0             0.0
# 15663    -122.44     37.80                52.0       3830.0             0.0
# 20484    -118.72     34.28                17.0       3051.0             0.0
# 9814     -121.93     36.62                34.0       2351.0             0.0
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0           201.0
# 11964    -117.43     34.02                33.0       3084.0           570.0
# 5390     -118.38     34.03                36.0       2101.0           569.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 15795    -122.42     37.77                52.0       4226.0          1315.0
#
#        population  households  median_income
# ...

# %%
n_train=int(0.6*n)
n_val=int(0.2*n)
n_test=int(0.2*n)
n_train,n_val,n_test
# Out:
# (12384, 4128, 4128)

# %%
df1_train=df1_shuffled.iloc[n_train:]
df1_val=df1_shuffled.iloc[n_val:n_train+n_val]
df1_test=df1_shuffled.iloc[n_train+n_val:]

# %%
df1_train[['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income']]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19660    -120.85     37.51                15.0       1131.0           285.0
# 4415     -118.25     34.09                52.0       1866.0           470.0
# 18113    -122.02     37.31                34.0       2629.0           433.0
# 17673    -121.88     37.30                16.0       2692.0           749.0
# 16992    -122.27     37.56                17.0       3211.0           847.0
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0           201.0
# 11964    -117.43     34.02                33.0       3084.0           570.0
# 5390     -118.38     34.03                36.0       2101.0           569.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 15795    -122.42     37.77                52.0       4226.0          1315.0
#
#        population  households  median_income
# ...

# %%
df1_val[['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income']]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
# ...          ...       ...                 ...          ...             ...
# 20011    -119.12     36.05                27.0       1575.0           321.0
# 12225    -116.90     33.65                15.0        652.0           149.0
# 1051     -120.71     38.34                16.0       1257.0           231.0
# 14519    -117.13     32.91                16.0       2715.0           581.0
# 11410    -117.93     33.71                10.0       2775.0           717.0
#
#        population  households  median_income
# ...

# %%
df1_test[['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income']]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9221     -120.26     37.13                33.0       1239.0           250.0
# 10234    -117.91     33.86                26.0       2296.0           570.0
# 4763     -118.36     34.04                48.0       1769.0           429.0
# 9062     -118.15     34.69                32.0       1300.0           234.0
# 1874     -119.97     38.93                24.0        856.0           185.0
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0           201.0
# 11964    -117.43     34.02                33.0       3084.0           570.0
# 5390     -118.38     34.03                36.0       2101.0           569.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 15795    -122.42     37.77                52.0       4226.0          1315.0
#
#        population  households  median_income
# ...

# %%
y_train=np.log1p(df_train.median_house_value.values)
y_val=np.log1p(df_val.median_house_value.values)
y_test=np.log1p(df_test.median_house_value.values)

# %%
del df_train['median_house_value']
del df_val['median_house_value']
del df_test['median_house_value']

# %%
len(y_train),len(df1_val),len(df1_test)
# Out:
# (8256, 12384, 4128)

# %%
df1_train[['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income']]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19660    -120.85     37.51                15.0       1131.0           285.0
# 4415     -118.25     34.09                52.0       1866.0           470.0
# 18113    -122.02     37.31                34.0       2629.0           433.0
# 17673    -121.88     37.30                16.0       2692.0           749.0
# 16992    -122.27     37.56                17.0       3211.0           847.0
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0           201.0
# 11964    -117.43     34.02                33.0       3084.0           570.0
# 5390     -118.38     34.03                36.0       2101.0           569.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 15795    -122.42     37.77                52.0       4226.0          1315.0
#
#        population  households  median_income
# ...

# %%
xi=df1_train[['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income']].iloc[1000]
xi
# Out:
# longitude             -118.4700
# latitude                34.0200
# housing_median_age      35.0000
# total_rooms           3057.0000
# total_bedrooms         774.0000
# population            2223.0000
# households             732.0000
# median_income            2.0745
# Name: 8919, dtype: float64

# %%
mh=df.loc[:,'median_house_value']
mh
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %%
mh.mean()
# Out:
# 206855.81690891474

# %%
mh.median()
# Out:
# 179700.0

# %%
mh.describe()
# Out:
# count     20640.000000
# mean     206855.816909
# std      115395.615874
# min       14999.000000
# 25%      119600.000000
# 50%      179700.000000
# 75%      264725.000000
# max      500001.000000
# Name: median_house_value, dtype: float64

# %%
df1_train.iloc[1000]
# Out:
# longitude               -118.47
# latitude                  34.02
# housing_median_age         35.0
# total_rooms              3057.0
# total_bedrooms            774.0
# population               2223.0
# households                732.0
# median_income            2.0745
# median_house_value     332500.0
# ocean_proximity       <1H OCEAN
# Name: 8919, dtype: object

# %%
xi=np.log1p(df1_train.median_house_value.values)
# Out:
# array([11.4414402 , 12.15162174, 12.74081302, ..., 12.31088751,
#        12.55497093, 12.69158354])

# %%
w=[0.0001,0.0001,0.004,0.003,0.002,0.005,0.0002,0.001]

# %%
def dot(xi,w):
    n=len(xi)
    res=5.17
    for j in range(n):
        res=res+xi[j]*w[j]
        return res

# %%
def linear_regression(xi):
    return w0+dot(xi,w)

# %%
linear_regression(xi)
# Out:
# 10.340153

# %%
np.expm1(10.347144144020435)
# Out:
# 31166.904550582654

# %%
# using mean to fill the missing value

# %%
df2=df.fillna(537.8705525375618)
df2
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
n=len(df2)
n
# Out:
# 20640

# %%
idx=np.arange(n)

# %%
np.random.seed(42)

# %%
np.random.shuffle(idx)

# %%
df2_shuffled=df2.iloc[idx]
df2_shuffled
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20046    -119.01     36.06                25.0       1505.0      537.870553
# 3024     -119.46     35.14                30.0       2943.0      537.870553
# 15663    -122.44     37.80                52.0       3830.0      537.870553
# 20484    -118.72     34.28                17.0       3051.0      537.870553
# 9814     -121.93     36.62                34.0       2351.0      537.870553
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0      201.000000
# 11964    -117.43     34.02                33.0       3084.0      570.000000
# 5390     -118.38     34.03                36.0       2101.0      569.000000
# 860      -121.96     37.58                15.0       3575.0      597.000000
# 15795    -122.42     37.77                52.0       4226.0     1315.000000
#
# ...

# %%
df2_shuffled[['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','median_income']]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20046    -119.01     36.06                25.0       1505.0      537.870553
# 3024     -119.46     35.14                30.0       2943.0      537.870553
# 15663    -122.44     37.80                52.0       3830.0      537.870553
# 20484    -118.72     34.28                17.0       3051.0      537.870553
# 9814     -121.93     36.62                34.0       2351.0      537.870553
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0      201.000000
# 11964    -117.43     34.02                33.0       3084.0      570.000000
# 5390     -118.38     34.03                36.0       2101.0      569.000000
# 860      -121.96     37.58                15.0       3575.0      597.000000
# 15795    -122.42     37.77                52.0       4226.0     1315.000000
#
#        population  households  median_income
# ...

# %%
n_train=int(0.6*n)
n_val=int(0.2*n)
n_test=int(0.2*n)
n_train,n_val,n_test
# Out:
# (12384, 4128, 4128)

# %%
df2_train=df2_shuffled.iloc[n_train:]
df2_val=df2_shuffled.iloc[n_val:n_train+n_val]
df2_test=df2_shuffled.iloc[n_train+n_val:]

# %%
df2_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19660    -120.85     37.51                15.0       1131.0           285.0
# 4415     -118.25     34.09                52.0       1866.0           470.0
# 18113    -122.02     37.31                34.0       2629.0           433.0
# 17673    -121.88     37.30                16.0       2692.0           749.0
# 16992    -122.27     37.56                17.0       3211.0           847.0
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0           201.0
# 11964    -117.43     34.02                33.0       3084.0           570.0
# 5390     -118.38     34.03                36.0       2101.0           569.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 15795    -122.42     37.77                52.0       4226.0          1315.0
#
# ...

# %%
df2_train.iloc[1000]
# Out:
# longitude               -118.47
# latitude                  34.02
# housing_median_age         35.0
# total_rooms              3057.0
# total_bedrooms            774.0
# population               2223.0
# households                732.0
# median_income            2.0745
# median_house_value     332500.0
# ocean_proximity       <1H OCEAN
# Name: 8919, dtype: object

# %%
xk=np.log1p(df2_train.median_house_value.values)
xk
# Out:
# array([11.4414402 , 12.15162174, 12.74081302, ..., 12.31088751,
#        12.55497093, 12.69158354])

# %%
w=[0.0001,0.0001,0.004,0.003,0.002,0.005,0.0002,0.001]

# %%
def dot(xk,w):
    n=len(xk)
    res=5.17
    for j in range(n):
        res=res+xk[j]*w[j]
        return res

# %%
def linear_regression(xk):
    return w0+dot(xk,w)

# %%
linear_regression(xk)
# Out:
# 10.347144144020435

# %%
np.expm1(10.347144144020435)
# Out:
# 31166.904550582654
